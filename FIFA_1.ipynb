# %%
import pandas as pd 
import numpy as np

# %%
df1 = pd.read_csv('data_mid_bootcamp_project_FIFA_MoneyBall-master/fifa21_male2.csv',encoding="ISO-8859-1" )
# Out:
# /var/folders/bg/4d0w7gdx0578w94pqg4phn080000gn/T/ipykernel_7612/3277220021.py:1: DtypeWarning: Columns (78) have mixed types. Specify dtype option on import or set low_memory=False.
#   df1 = pd.read_csv('data_mid_bootcamp_project_FIFA_MoneyBall-master/fifa21_male2.csv',encoding="ISO-8859-1" )

# %%
pwd!
# Out:
# '/Users/yun/Documents/IronHack/MINI_PROYEC1'

# %%
df1.head(4)
# Out:
#    ID          Name  Age  OVA            Nationality           Club  BOV   BP  \
# 0   2   G. Pasquale   33   69                  Italy        Udinese   71  LWB
# 1  16  Luis GarcÃ­a   37   71                  Spain      KAS Eupen   70   CM
# 2  27       J. Cole   33   71                England  Coventry City   71  CAM
# 3  36      D. Yorke   36   68  Trinidad &amp; Tobago     Sunderland   70   ST
#
#        Position                                       Player Photo  ...  \
# 0            LM  https://cdn.sofifa.com/players/000/002/16_120.png  ...
# 1    CM CAM CDM  https://cdn.sofifa.com/players/000/016/19_120.png  ...
# 2  CAM RM RW LM  https://cdn.sofifa.com/players/000/027/16_120.png  ...
# 3           NaN  https://cdn.sofifa.com/players/000/036/09_120.png  ...
#
#      CDM    RDM    RWB     LB   LCB    CB   RCB     RB    GK Gender
# 0  70+-1  70+-1  71+-2  70+-1  69+0  69+0  69+0  70+-1  17+0   Male
# 1   66+1   66+1   62+1   60+1  60+1  60+1  60+1   60+1  17+1   Male
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17125 entries, 0 to 17124
# Columns: 107 entries, ID to Gender
# dtypes: float64(10), int64(45), object(52)
# memory usage: 14.0+ MB

# %%
df1.dtypes
# Out:
# ID              int64
# Name           object
# Age             int64
# OVA             int64
# Nationality    object
#                 ...
# CB             object
# RCB            object
# RB             object
# GK             object
# Gender         object
# Length: 107, dtype: object

# %%
df1_fifa = df1.dropna()
df1_fifa.head(8)
# Out:
#           ID           Name  Age  OVA Nationality  \
# 230    50598        D. Bent   33   70     England
# 486   140038  J. RodrÃ­guez   37   67      Mexico
# 550   143809       M. Demir   28   70      Turkey
# 702   156358      M. MuÃ±oz   37   71      Mexico
# 748   157804      S. Carson   34   70     England
# 822   161733       J. Rivas   33   67      Mexico
# 1047  168444            Ari   31   77      Brazil
# 1070  169078     L. Freeman   28   72     England
#
#                              Club  BOV   BP Position  \
# 230                 Burton Albion   69   ST       ST
# 486              Monarcas Morelia   67   CM   CDM CM
# 550     GaziÅehir Gaziantep F.K.   71   CF   ST CAM
# 702                     Puebla FC   70   GK       GK
# 748               Manchester City   70   GK       GK
# 822   Tiburones Rojos de Veracruz   66   CB    CB LB
# 1047             Lokomotiv Moscow   76   ST    ST RW
# 1070            Nottingham Forest   72  CAM   CAM LM
#
# ...

# %%
df1_fifa.columns=df1_fifa.columns.str.lower().str.replace(' ','_')

# %%
pd.DataFrame(df1_fifa.columns.sort_values())
# Out:
#                 0
# 0             a/w
# 1    acceleration
# 2             age
# 3      aggression
# 4         agility
# ..            ...
# 102        vision
# 103       volleys
# 104           w/f
# 105          wage
# 106        weight
#
# [107 rows x 1 columns]

# %%
df1_fifa.dropna()
# Out:
#            id           name  age  ova  nationality  \
# 230     50598        D. Bent   33   70      England
# 486    140038  J. RodrÃ­guez   37   67       Mexico
# 550    143809       M. Demir   28   70       Turkey
# 702    156358      M. MuÃ±oz   37   71       Mexico
# 748    157804      S. Carson   34   70      England
# ...       ...            ...  ...  ...          ...
# 16938  258627     O. Edwards   19   59      England
# 17044  258883        B. Webb   19   53      England
# 17057  258908   J. van Hecke   20   67  Netherlands
# 17071  258938      L. Borges   19   60      Germany
# 17120  259088     A. Medioub   22   64       France
#
#                             club  bov  bp position  \
# 230                Burton Albion   69  ST       ST
# 486             Monarcas Morelia   67  CM   CDM CM
# 550    GaziÅehir Gaziantep F.K.   71  CF   ST CAM
# 702                    Puebla FC   70  GK       GK
# 748              Manchester City   70  GK       GK
# ...

# %%
df1_fifa.drop(['w/f', 'ir','sm','a/w','d/w','lcb','pac', 'sho', 'pas', 'cb', 'dri', 'def' , 'phy', 'ls', 'rcb','st' ,'rs', 'lw','lf','cf','rb', 'rf' , 'rw','lam', 'cam','ram' , 'gk', 'lm' , 'lcm','cm' ,'rcm', 'rm', 'lwb', 'cdm','rdm', 'rwb', 'lb' ,'gender' ], axis=1, inplace=True)
# Out:
# /var/folders/bg/4d0w7gdx0578w94pqg4phn080000gn/T/ipykernel_7612/2108988835.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1_fifa.drop(['w/f', 'ir','sm','a/w','d/w','lcb','pac', 'sho', 'pas', 'cb', 'dri', 'def' , 'phy', 'ls', 'rcb','st' ,'rs', 'lw','lf','cf','rb', 'rf' , 'rw','lam', 'cam','ram' , 'gk', 'lm' , 'lcm','cm' ,'rcm', 'rm', 'lwb', 'cdm','rdm', 'rwb', 'lb' ,'gender' ], axis=1, inplace=True)

# %%
df1_fifa.head(4)
# Out:
#          id           name  age  ova nationality                       club  \
# 230   50598        D. Bent   33   70     England              Burton Albion
# 486  140038  J. RodrÃ­guez   37   67      Mexico           Monarcas Morelia
# 550  143809       M. Demir   28   70      Turkey  GaziÅehir Gaziantep F.K.
# 702  156358      M. MuÃ±oz   37   71      Mexico                  Puebla FC
#
#      bov  bp position                                       player_photo  ...  \
# 230   69  ST       ST  https://cdn.sofifa.com/players/050/598/18_120.png  ...
# 486   67  CM   CDM CM  https://cdn.sofifa.com/players/140/038/18_120.png  ...
# 550   71  CF   ST CAM  https://cdn.sofifa.com/players/143/809/20_120.png  ...
# 702   70  GK       GK  https://cdn.sofifa.com/players/156/358/18_120.png  ...
#
#     goalkeeping gk_diving  gk_handling gk_kicking gk_positioning gk_reflexes  \
# 230          44         8            9         13              6           8
# ...

# %%
df1_fifa = df1_fifa.astype({'volleys': 'int64' , 'curve': 'int64', 'balance': 'int64', 'jumping': 'int64' , 'interceptions': 'int64' , 'positioning': 'int64' , 'vision': 'int64' , 'sliding_tackle': 'int64'})
df1_fifa.dtypes
# Out:
# id              int64
# name           object
# age             int64
# ova             int64
# nationality    object
#                 ...
# gk_reflexes     int64
# total_stats     int64
# base_stats      int64
# hits           object
# ldm            object
# Length: 69, dtype: object

# %%
df1_fifa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 895 entries, 230 to 17120
# Data columns (total 69 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                895 non-null    int64
#  1   name              895 non-null    object
#  2   age               895 non-null    int64
#  3   ova               895 non-null    int64
#  4   nationality       895 non-null    object
#  5   club              895 non-null    object
#  6   bov               895 non-null    int64
#  7   bp                895 non-null    object
#  8   position          895 non-null    object
#  9   player_photo      895 non-null    object
#  10  club_logo         895 non-null    object
#  11  flag_photo        895 non-null    object
#  12  pot               895 non-null    int64
#  13  team_&_contract   895 non-null    object
#  14  height            895 non-null    object
#  15  weight            895 non-null    object
# ...

# %%
 df1_fifa.head(4)
# Out:
#          id           name  age  ova nationality                       club  \
# 230   50598        D. Bent   33   70     England              Burton Albion
# 486  140038  J. RodrÃ­guez   37   67      Mexico           Monarcas Morelia
# 550  143809       M. Demir   28   70      Turkey  GaziÅehir Gaziantep F.K.
# 702  156358      M. MuÃ±oz   37   71      Mexico                  Puebla FC
#
#      bov  bp position                                       player_photo  ...  \
# 230   69  ST       ST  https://cdn.sofifa.com/players/050/598/18_120.png  ...
# 486   67  CM   CDM CM  https://cdn.sofifa.com/players/140/038/18_120.png  ...
# 550   71  CF   ST CAM  https://cdn.sofifa.com/players/143/809/20_120.png  ...
# 702   70  GK       GK  https://cdn.sofifa.com/players/156/358/18_120.png  ...
#
#     goalkeeping gk_diving  gk_handling gk_kicking gk_positioning gk_reflexes  \
# 230          44         8            9         13              6           8
# ...

# %%
df1_fifa = df1_fifa.astype({'value': 'float64', 'wage'':'float64', 'relase_clause': 'float64'})
df1_fifa.dtypes
# Out:
#   Cell In[28], line 1
#     df1_fifa = df1_fifa.astype({'value': 'float64', 'wage'':'float64', 'relase_clause': 'float64'})
#                                                              ^
# SyntaxError: invalid syntax

# %%
df1_fifa['value']=df1_fifa['value'].str.replace('â¬','')

# %%
df1_fifa['wage']=df1_fifa['wage'].str.replace('â¬','')

# %%
df1_fifa.to_csv('fifa21f.csv', header=True, index=False)
